# %%
import pandas as pd


df = pd.read_csv("sequential.csv", delimiter=",", dtype=pd.Timedelta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import pandas as pd
# ----> 4 df = pd.read_csv("sequential.csv", delimiter=",", dtype=pd.Timedelta)
#
# ...

# %%
df['TOTAL']
# Out:
# 0     1241022973ns
# 1     1270024605ns
# 2     1238062116ns
# 3     1285614111ns
# 4     1266805820ns
# 5     1244599147ns
# 6     1255194629ns
# 7     1230785171ns
# 8     1354090843ns
# 9     1327140805ns
# 10    1308280400ns
# 11    1253148797ns
# 12    1276314371ns
# 13    1246799807ns
# 14    1255815204ns
# 15    1242352897ns
# 16    1278376266ns
# 17    1231274053ns
# 18    1272406673ns
# 19    1223905960ns
# 20    1228484190ns
# 21    1216978908ns
# 22    1219873827ns
# 23    1209614911ns
# 24    1227888372ns
# 25    1216984757ns
# 26    1209857354ns
# 27    1218801353ns
# 28    1210176580ns
# 29    1218003769ns
# 30    1222110330ns
# 31    1212337979ns
# 32    1231442902ns
# 33    1209933201ns
# 34    1222185707ns
# 35    1216500030ns
# 36    1208839258ns
# 37    1211045472ns
# 38    1217536168ns
# 39    1220861381ns
# 40    1235634602ns
# 41    1216999873ns
# 42    1223863519ns
# 43    1216098578ns
# 44    1209852250ns
# 45    1232458851ns
# 46    1224124428ns
# ...

# %%
total.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 total.median()
#
# File ~/CLionProjects/spm-project/benchmark_workspace/venv/lib/python3.11/site-packages/pandas/core/series.py:6231, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6223 @doc(make_doc("median", ndim=1))
#    6224 def median(
#    6225     self,
#    (...)
#    6229     **kwargs,
#    6230 ):
# -> 6231     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/CLionProjects/spm-project/benchmark_workspace/venv/lib/python3.11/site-packages/pandas/core/generic.py:11989, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11982 def median(
#   11983     self,
#   11984     axis: Axis | None = 0,
#    (...)
#   11987     **kwargs,
#   11988 ) -> Series | float:
# > 11989     return self._stat_function(
# ...

# %%
x, y = df['READING'], df['TOTAL']

# %%
import matplotlib.pyplot as plt

plt.title("Execution time")
#plt.yscale('log')
plt.plot(x, y, '-bo')

plt.xticks(range(0, 21))
plt.xlabel("P")
plt.ylabel("Time [us]")

plt.show()
